# %%
import torch
from models import BFA_modules
import matplotlib.pyplot as plt

# %% [markdown]
# ### Initialize semantic diffusion module

# %%
diffusion = BFA_modules.Diffusion(max_step=100000)

# %% [markdown]
# ### Load data

# %%
weights = torch.load('weights.pt')
feat_in = torch.load('feat_in.pt')

# %%
print(weights.shape, feat_in.shape)
# Out:
# torch.Size([1, 128, 9, 61, 61]) torch.Size([1, 128, 61, 61])

# %% [markdown]
# ### Feature map before semantic diffusion

# %%
plt.imshow(feat_in[0,:,:,:].sum(0))

# %% [markdown]
# ### Diffusion process

# %%
after_diff = diffusion(feat_in, weights)

# %% [markdown]
# ### Feature map after semantic diffusion

# %%
plt.imshow(after_diff[0,:,:,:].sum(0))
